# %%
# %load_ext octavemagic

# %%
# %%octave
#
# pkg load statistics
# ap = load_appliance_parameters();
#
#
# for idx=1:14
#     appliance=ap(idx);
#     figure
#     plot(hmmgenerate(100, appliance.transition_matrix, appliance.emission_matrix));
#     title(appliance.name)
# end
# Out:
# ...
# Some output formats are not available.
# ...
# Some output formats are not available.
# ...
# Some output formats are not available.
