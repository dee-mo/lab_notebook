# %% [markdown]
# # 2013-03-15
# # matlab HMM warmup

# %%
# %load_ext octavemagic

# %%
# %%octave
# pkg load statistics
#
# % hidden state 1 is off
# % hidden state 2 is on
#
# % observable state 1 is off (low power)
# % observable state 2 is on (high power)
#
# % simulation begins with all in state 1 (off) and then transition matrix
# % is applied for first hidden and observed states
#
# on_to_on = 0.90;
# on_to_off = 1.0 - on_to_on;
# off_to_off = 0.01;
# off_to_on = 1.0 - off_to_off;
#
# % this matrix seems to be transposed from what i expect
# % TRANS(i,j) is the probability of transition from state i to state j.
# % transition_matrix = [p(1|1) p(2|1); p(1|2) p(2|2)]
# transition_matrix = [off_to_off, off_to_on; on_to_off, on_to_on];
#
# % EMIS(k,l) is the probability that symbol l is emitted from state k.
# emission_matrix = [1.0, 0.0; 0.0, 1.0];
#
# num_steps = 100;
# [sequence, states] = hmmgenerate(num_steps, transition_matrix, emission_matrix);
#
# plot(sequence, 'kx-')
#
# %states
# %sequence
