# %%
ls
# Out:
# 2013/                            2013-04-07-cycle-life.ipynb
# 2013-04-04-bboxx.ipynb           2013-04-07-embed-image.ipynb
# 2013-04-04-pap-homer.ipynb       2013-04-07-pandas-masking.ipynb
# 2013-04-05-wp10-storage.ipynb    photo.JPG
# 2013-04-07-curvefit.ipynb

# %%
from IPython.core.display import Image
Image(filename='photo.JPG', embed=True)
