# %% [markdown]
# # 2013-03-19
# # Simulated appliance ownership

# %%
# %load_ext octavemagic
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
# %%octave -o user_app_num
#
# pkg load nan
#
# run load_survey_PaPim_20130216.m

# %% [markdown]
# The 2-D array
#
#     user_app_num
#
# holds the simulated number of appliances.  The first index of the array is the customer index and the second is the appliance index.  The function should probably return this array to be fed into the timeseries generator.

# %%
labels = ['incandescent', 'cfl', 'tube', 'led', 'vertfridge', 'chestfridge',
          'TV', 'DVD', 'radio', 'iron', 'ceilfan', 'floorfan', 'mixer', 'laptop']

# %%
ax = subplot(111)
ax.imshow(user_app_num, aspect=0.01, interpolation='none')
ax.set_xticks(range(len(labels)))
ax.set_xticklabels(labels, rotation='vertical')
show()
