# %% [markdown]
# #2013-03-08

# %%
# %pylab inline
# %load_ext octavemagic
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
# run dan's script and output main values to ipython namespace

# %%octave -o p_table,power_tot

run portapiment_grid_20130306.m

# %% [markdown]
# Quick and dirty histogram of all power values created by taking all the power values and flattening them and converting to a series for easier manipulation and plotting.
#
# The distribution appears skewed and also has a flat shelf on the low end.

# %%
import pandas as pd
pdf = pd.Series(p_table.flatten())
pdf.hist(bins=50)
ylabel('Frequency')
xlabel('Power Level')
title('Portapiment Power Histogram')

# %% [markdown]
# Creating a quick fft of data.  Dropping the NAN values adds some spurious frequency content.  I think the bands at the end are in the higher frequency content.  I must review FFT and plot this with a proper frequency axis.

# %%
p_dna = pdf.dropna().values
pfft = fft.fft(p_dna)
plot(pfft)
ylim((-2500, 2500))
# Out:
# (-2500, 2500)
