# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %%
time = linspace(0, 0.05, 101)

# %%
plot(time, cos(time * 2 * pi * 60))
plot(time, cos(time * 2 * pi * 60)*cos(time * 2 * pi * 60))
grid()

# %%
sqrt(sum(cos(time*2 * pi*60)**2)/0.05)
# Out:
# 31.937438845342616

# %%
time = linspace(0, 2*pi, 100)

# %%
plot(time, cos(time)**2)
grid()
