# %% [markdown]
# # CRF

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
rate = linspace(0.00, 0.50, 11)
rate
# Out:
# array([ 0.  ,  0.05,  0.1 ,  0.15,  0.2 ,  0.25,  0.3 ,  0.35,  0.4 ,
#         0.45,  0.5 ])

# %%
CRF = -pmt(rate, 10., 1.)
# Out:
# /Users/dsoto/anaconda/envs/py33/lib/python3.3/site-packages/numpy/lib/financial.py:208: RuntimeWarning: invalid value encountered in true_divide
#   fact = np.where(rate==zer, nper+zer, (1+rate*when)*(temp-1)/rate+zer)

# %%
plot(rate, CRF)
plot(rate, rate)
xlabel('Interest Rate')
ylabel('CRF'); ylim((0, 0.5))
title('Capital Recovery Factor')
grid()
