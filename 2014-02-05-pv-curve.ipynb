# %% [markdown]
# # simple plotting demonstration

# %%
# %pylab inline

resistance = array([100, 200, 300, 1000, 2000, 3000]) 
voltage = array([1, 1.5, 2, 3.5, 4, 5])

current = voltage / resistance
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
current
# Out:
# array([ 0.01      ,  0.0075    ,  0.00666667,  0.0035    ,  0.002     ,
#         0.00166667])

# %%
plot(voltage, current)
xlabel('Voltage (V)')
ylabel('Current (A)')
